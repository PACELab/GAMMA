# %%
import pandas as pd

# %%
baseline = "/home/ubuntu/firm_compass/traces/bottleneck_dataset/experiments/baseline_traces_800_0/compose_1"
df = pd.read_csv(baseline)
bottlenecked_services = ["post-storage-service", "social-graph-service"]

# %%
df.filter(regex="|".join(bottlenecked_services)).describe()
# Out:
#        post-storage-service_StorePost_MongoInsertPost  \
# count                                     7205.000000
# mean                                      1237.935739
# std                                        736.328640
# min                                        467.000000
# 25%                                        887.000000
# 50%                                       1050.000000
# 75%                                       1338.000000
# max                                      16681.000000
#
#        post-storage-service_UploadText_StorePost  \
# count                                7205.000000
# mean                                 1300.296738
# std                                   762.069367
# min                                   496.000000
# 25%                                   934.000000
# 50%                                  1100.000000
# 75%                                  1404.000000
# max                                 16722.000000
#
# ...

# %%
b = "/home/ubuntu/firm_compass/traces/bottleneck_dataset/experiments/bottlenecked_traces_repeat_800_0/compose_41"
df_b = pd.read_csv(b)

# %%
df_b.filter(regex="|".join(bottlenecked_services)).describe()
# Out:
#        post-storage-service_StorePost_MongoInsertPost  \
# count                                     5053.000000
# mean                                      2114.710469
# std                                       2014.822778
# min                                        461.000000
# 25%                                       1028.000000
# 50%                                       1417.000000
# 75%                                       2292.000000
# max                                      35225.000000
#
#        post-storage-service_UploadText_StorePost  \
# count                                5053.000000
# mean                                 2273.895508
# std                                  2239.237943
# min                                   483.000000
# 25%                                  1076.000000
# 50%                                  1491.000000
# 75%                                  2459.000000
# max                                 35264.000000
#
# ...
